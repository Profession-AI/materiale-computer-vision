# %% [markdown]
# # **YOLO con ultralytics**
#
# - ultralytics GitHub: https://github.com/ultralytics/ultralytics

# %%
! pip install ultralytics --q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 4.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %%
import requests

image_url = "https://ultralytics.com/images/bus.jpg"

img_data = requests.get(image_url).content
with open('test.jpg', 'wb') as f:
    f.write(img_data)

# %%
model = YOLO('yolov8m.pt')  # pretrained YOLOv8n model
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8m.pt to 'yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 197MB/s]

# %%
results = model(['test.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    # print(result)
    # boxes = result.boxes  # Boxes object for bounding box outputs
    # print(boxes)
    # probs = result.probs  # Probs object for classification outputs
    result.save(filename='result.jpg')  # save to disk
# Out:
# 0: 640x480 4 persons, 1 bus, 1759.0ms
# Speed: 4.2ms preprocess, 1759.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)

# %%
image = Image.open('result.jpg')
plt.imshow(image)
